# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from scipy import signal
from tools import *

from sklearn.decomposition import NMF, PCA

from scipy.sparse import *
from scipy.io import mmread

# Import auryn tools
sys.path.append(os.path.expanduser("~/auryn/tools/python/"))
from auryntools import *
from matplotlib import animation, rc
from IPython.display import HTML
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import tools
import elephant
import quantities as pq
from neo.core import SpikeTrain
import viziphant
from pyvis.network import Network
import networkx as nx
import pandas as pd

# %%
dure_simu = 14400
begining_presentation = 0
duree_pattern = 0.05
time_step = 0.01
auryn_tstep = 0.0001
spls = dure_simu/time_step

# %%
deb = 14355.25
dur = 2
beg = int(deb//time_step)
end = beg+int(dur//time_step)

# %%
num_mpi_ranks = 4 # the number of sims you used in parallel
datadir = os.path.expanduser("/mnt/data1/data_paul/sim_less_stim_neurons_more_inside_connect_nocons_suit_pat") # Set this to your data path
prefix = "rf1"

nb_neurons = 4096

# %%
all_times = np.genfromtxt(datadir+'/pattern_times', delimiter=' ')
nb_pattern = len(set(all_times[:,1]))
signals = np.zeros((nb_pattern,int(dure_simu//time_step)+1))
signals_times = [[] for i in range(nb_pattern)]
for time,kind in all_times:
    signals_times[int(kind)].append(time*auryn_tstep)
    signals[int(kind),int((time)//time_step):int((time+(duree_pattern))//time_step)]=1

# %%
signals_times[]
# Out:
# [[1.2370000000000002e-05,
#   5.0060000000000005e-05,
#   0.00011258999999999999,
#   0.00022478,
#   0.00024047,
#   0.00030419,
#   0.00034978,
#   0.00036993000000000003,
#   0.00038696000000000005,
#   0.00041262,
#   0.00044399,
#   0.00048629,
#   0.0005080400000000001,
#   0.00053655,
#   0.00055886,
#   0.0005785300000000001,
#   0.0006106,
#   0.00064278,
#   0.00065805,
#   0.0006891200000000001,
#   0.0007174600000000001,
#   0.00076528,
#   0.00085016,
#   0.0009015700000000001,
#   0.00093064,
#   0.0009566000000000002,
#   0.00101098,
#   0.00105076,
#   0.0011237,
#   0.00114261,
#   0.00116456,
#   0.0011945,
#   0.00128168,
#   0.00133214,
#   0.00137432,
#   0.00140476,
#   0.00142671,
#   0.0014496300000000001,
#   0.00150222,
#   0.00153418,
#   0.0016228400000000002,
#   0.0016429400000000003,
#   0.00170553,
#   0.00175099,
#   0.0017703900000000002,
#   0.00181328,
#   0.00183938,
#   0.0018589700000000002,
#   0.0018763200000000001,
#   0.00191528,
#   0.00193371,
#   0.00196925,
#   0.00199429,
#   0.00204208,
#   0.00206118,
#   0.00208966,
#   0.00212109,
#   0.00216013,
#   0.00219807,
#   0.0022287400000000003,
#   0.00225371,
#   0.00229253,
#   0.00231209,
#   0.00233247,
#   0.00235916,
#   0.0023926900000000003,
#   0.00240951,
#   0.00242728,
#   0.00244668,
#   0.00249791,
#   0.0025176200000000004,
#   0.00253659,
#   0.0025572800000000003,
#   0.00259423,
#   0.0026369,
#   0.00269576,
#   0.00271219,
#   0.0027333400000000003,
#   0.00275725,
#   0.00279663,
#   0.00282898,
#   0.0028464700000000002,
#   0.00286209,
#   0.00288535,
#   0.00290807,
#   0.0029808700000000005,
#   0.00300992,
#   0.0031124800000000004,
#   0.03335487,
#   0.03337283,
#   0.033414400000000004,
#   0.03343854,
#   0.03349652,
#   0.03352349,
#   0.03355474,
#   0.03359944,
#   0.03363384,
#   0.03368032,
#   ...]]

# %% [markdown]
# # Find low rank structure in spiking activity

# %%
spkfiles  = ["%s/%s.%i.e.spk"%(datadir,prefix,i) for i in range(num_mpi_ranks)]
sfo = AurynBinarySpikeView(spkfiles)
# Out:
# Warning! Version mismatch between the decoding tool and the file version.
# AurynBinarySpikeFile (0, 8, 1)
# Fileversion (0, 8, 2)
# Warning! Version mismatch between the decoding tool and the file version.
# AurynBinarySpikeFile (0, 8, 1)
# Fileversion (0, 8, 2)
# Warning! Version mismatch between the decoding tool and the file version.
# AurynBinarySpikeFile (0, 8, 1)
# Fileversion (0, 8, 2)
# Warning! Version mismatch between the decoding tool and the file version.
# AurynBinarySpikeFile (0, 8, 1)
# Fileversion (0, 8, 2)

# %%
#spkext = pd.read_csv("%s/%s.%i.spikes_ext.txt"%(datadir,prefix,0),delimiter=' ').values
extfiles  = ["%s/%s.%i.ext.spk"%(datadir,prefix,i) for i in range(1)]
sfo_ext = AurynBinarySpikeView(extfiles)
# Out:
# Warning! Version mismatch between the decoding tool and the file version.
# AurynBinarySpikeFile (0, 8, 1)
# Fileversion (0, 8, 2)

# %%
rateE  = np.mean([pd.read_csv("%s/%s.%i.e.prate"%(datadir,prefix,2),delimiter=' ').values for i in range(num_mpi_ranks)],axis=0)

# %%
time_axis = np.linspace(0,dure_simu,int(dure_simu//time_step))
rateE= rateE[:,1]

# %%
plt.plot(time_axis,rateE)

# %%
plt.plot(time_axis[beg:end],rateE[beg:end])
plt.plot(time_axis[beg:end],signals[0][beg:end]*10)

# %%
plt.plot(rateE[beg:end])
plt.plot(signals[0][beg:end]*10)

# %%
rateI  = np.mean([pd.read_csv("%s/%s.%i.i2.prate"%(datadir,prefix,i),,delimiter=' ' ) for i in range(num_mpi_ranks)],axis=0)
time_axis_I = rateI[:,0]
rateI= rateI[:,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d5d04dafcbf7> in <module>
# ----> 1 rateI  = np.mean([pd.read_csv("%s/%s.%i.i2.prate"%(datadir,prefix,i)) for i in range(num_mpi_ranks)],axis=0)
#       2 time_axis_I = rateI[:,0]
#       3 rateI= rateI[:,1]
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3370             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3371
# -> 3372     return _methods._mean(a, axis=axis, dtype=dtype,
#    3373                           out=out, **kwargs)
#    3374
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
# --> 162         ret = um.true_divide(
#     163                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     164         if is_float16_result and out is None:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
plt.plot(time_axis_I,rateI)

# %%
plt.plot(time_axis_I[beg:end],rateI[beg:end])
plt.plot(time_axis[beg:end],signals[0][beg:end]*10)

# %%
win = signal.windows.hann(1000)
plt.plot(np.convolve(rateE,win)/ sum(win))

# %%
win = signal.windows.hann(1000)
plt.plot(np.convolve(rateI,win)/ sum(win))

# %% [markdown]
# ## Raster Plot illustrant la reaction du system

# %%
#spikes_rast = np.array(sfo.get_spikes(t_start=7100,t_stop=7202))
spikes_rast_ext = np.array(sfo_ext.get_spikes(t_start=7100,t_stop=7102))

# %%
spikes_rast_ext
# Out:
# array([[7100.    , 3315.    ],
#        [7100.0001,  905.    ],
#        [7100.0001, 1139.    ],
#        ...,
#        [7102.    ,   47.    ],
#        [7102.    , 2142.    ],
#        [7102.    , 3341.    ]])

# %%
colors = in_pattern(spikes_rast_ext, duree_pattern, signals_times[0])

# %%
sample_ext = np.random.choice(list(range(nb_neurons)),500)

# %%
def plot_profile(begin,end,title,nb_sample,nb_sample_ext,alpha = 1,signal = 0):
    tm_rast = begin
    time_range_rast = end
    beg_2 = int(tm_rast//time_step)
    end_2 = beg_2+int(time_range_rast//time_step)
    
    spikes_rast = np.array(sfo.get_spikes(t_start=tm_rast,t_stop=tm_rast+time_range_rast))
    sample = np.random.choice(list(range(nb_neurons)),nb_sample)
    spikes_rast_sample = np.array([i for i in spikes_rast if i[1] in sample])

    spikes_rast_ext = np.array(sfo_ext.get_spikes(t_start=tm_rast,t_stop=tm_rast+time_range_rast))
    sample_ext = np.random.choice(list(range(nb_neurons)),nb_sample_ext)
    spikes_rast_sample_ext =np.array([i for i in spikes_rast_ext if i[1] in sample_ext])

    #not_to_fast_ones  = [ListTrains[li]  for li in range(len(ListTrains)) if len(ListTrains[li])<1000]mple_ext, duree_pattern, signals_times[signal])
    colors = in_pattern(spikes_rast_sample_ext,duree_pattern, signals_times[0])
    colors = ["r" if i ==1 else "b" for i in colors]
    
    fig, axs = plt.subplots(3,figsize=(8,10),sharex=True,gridspec_kw={'height_ratios': [2,2, 1]})
    fig.suptitle(title,y = 0.92,fontsize = 15)
    
    axs[0].scatter(spikes_rast_sample_ext[:,0], spikes_rast_sample_ext[:,1],alpha = alpha, c =colors,s = 18)
    axs[1].scatter(spikes_rast_sample[:,0], spikes_rast_sample[:,1],alpha = alpha, c="b",s = 18)
    axs[2].plot(time_axis[beg_2:end_2],rateE[beg_2:end_2])
    axs[2].plot(time_axis[beg_2:end_2],signals[signal][beg_2:end_2]*10)
    
    fig.add_subplot(111, frameon=False)
    plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
    plt.grid(False)
    plt.xlabel("Time (s)",fontsize = 12)
    #plt.ylabel("common Y",x = 0)

# %%
plot_profile(110.40,2,"before learning",1000,100)

# %%
plot_profile(14354.7,2,"After learning",1500,150)

# %%
spikes = np.array(sfo.get_spikes(t_start=14300,t_stop=14300+2))

# %%
tm = 7100
time_range = 100

# %%
which_signal = 0

# %%
times,dists = tools.SpikesDistFromPat(spikes[:,0],duree_pattern,signals_times[which_signal])

# %%
plt.hist(dists,bins=100);

# %%
ListTrains = [[] for _ in range(nb_neurons)] 
for s in spikes:
    ListTrains[int(s[1])].append(s[0])

# %%
distancesN = SpikesDistNeurones(spikes,duree_pattern,signals_times[which_signal],window = 0.15)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-5c6fd994971b> in <module>
# ----> 1 distancesN = SpikesDistNeurones(spikes,duree_pattern,signals_times[which_signal],window = 0.15)
#
# /export/home1/users/nsr/saighi/pub2015orchestrated/ana/tools.py in SpikesDistNeurones(spikeTrainN, duree_pattern, signal_times, window)
#     130                 r += 1
#     131             else:
# --> 132                 listdistN[int(neurones[spike_i])].append((spikeTrain[spike_i]-event,spikeTrain[spike_i]))
#     133
#     134
#
# IndexError: list index out of range

# %%
scores = np.array([ np.sum(np.logical_and(np.array(x)[:,0]<duree_pattern,np.array(x)[:,0]>0))/len(x) for x in distancesN if len(x)>0])

# %% [markdown]
# ### Certains neurones sont hyper actifs.

# %%
plt.hist(list(map(len,ListTrains)),bins=50);

# %% [markdown]
# ### Une minorité code bien le signal

# %%
plt.hist(scores,bins=50);

# %%
not_to_fast_ones  = [ListTrains[li]  for li in range(len(ListTrains)) if len(ListTrains[li])<1000]

# %% [markdown]
# ### Un neuron parfait ?

# %%
the_one = np.argmax(scores)

# %% [markdown]
# ### Et qui fire assez souvent. Si sont firing rate était à la ramasse, on aurait pu penser
# ### qu'il se serait fait attribué un bon score par accident.

# %%
lelu = SpikeTrain(ListTrains[the_one]*pq.s,t_start=min(ListTrains[the_one]),t_stop=max(ListTrains[the_one]))
len(ListTrains[the_one])
# Out:
# 213

# %%
distTrainOne = np.array(distancesN[the_one])

# %%
plt.scatter(distTrainOne[:,1],distTrainOne[:,0])

# %% [markdown]
# ### Des bons neurones

# %%
the_ones = np.where(scores>0.75)[0]

# %%
scatter_ones = np.sort([spike  for  n in the_ones for spike in ListTrains[n]])

# %%
times_ones ,dists_ones = tools.SpikesDistFromPat(scatter_ones,duree_pattern,signals_times[which_signal],window=0.2)

# %%
plt.scatter(times_ones,dists_ones)

# %%
trains = []
for i in the_ones:
    trains.append(ListTrains[i])
trains = np.sort(np.array([j for i in trains for j in i]))

# %%
lelu = SpikeTrain(trains*pq.s,t_start=min(trains),t_stop=max(trains))

# %%
signi_train =elephant.statistics.instantaneous_rate(lelu,1*pq.ms)

# %%
plt.plot(signi_train.times,signi_train/len(the_ones))
#plt.plot(time_axis[beg:end],signals[0][beg:end]*10)

# %% [markdown]
# # Load and analyze EE weights

# %%
wmatfiles  = ["%s/rf1.%i.ee.wmat"%(datadir,i) for i in range(num_mpi_ranks)]
w = np.sum( [ mmread(wf) for wf in wmatfiles ] )

# %%
h1 = plt.hist(w.data, bins=100, log=True)
plt.title("EE weight distribution")
sns.despine()

# %%
np.mean([i for i in w.data if i !=0])
# Out:
# 0.027438565609269664

# %%
connectivity_pat =[]
for n in the_ones:
    for n2 in the_ones:
        if w[n,n2] !=0:
            connectivity_pat.append([n,n2,w[n,n2]])
connectivity_pat = np.array(connectivity_pat)

# %% [markdown]
# ### Des neurones très connectés avec une activité liée dans le temps

# %%
v_co = connectivity_pat[np.argmax(connectivity_pat[:,2])]

# %%
v_co[0]
# Out:
# 784.0

# %%
distTrainPost = np.array(distancesN[int(v_co[1])])
distTrainPre = np.array(distancesN[int(v_co[0])])

# %%
plt.hist(distTrainPre[:,0],bins=50,alpha = 0.7);
plt.hist(distTrainPost[:,0],bins=50,alpha = 0.7);

# %%
most_connected_arg = connectivity_pat[connectivity_pat[:,2].argsort()[-50:][::-1]]
most_connected= most_connected_arg[:,[0,1]].ravel().astype(int)
scores_mst =scores[most_connected]

# %%
net = Network(notebook=True)
net.add_nodes(most_connected)
net.add_edges(most_connected_arg)

# %%
#net.show("my_network.html")
